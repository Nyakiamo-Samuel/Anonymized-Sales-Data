# %% [markdown]
# <a href="https://colab.research.google.com/github/Nyakiamo-Samuel/HR-Analysis/blob/main/HR_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the dependancies

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # HR DATA

# %%
hr_data=pd.read_csv('https://raw.githubusercontent.com/Nyakiamo-Samuel/HR-Analysis/refs/heads/main/HR%20data.csv')
hr_data.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   34      Travel_Rarely        790                   Sales
# 1   35      Travel_Rarely        660                   Sales
# 2   24  Travel_Frequently        381  Research & Development
# 3   24         Non-Travel        830                   Sales
# 4   44  Travel_Frequently       1193  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                24          4        Medical              1            1489
# 1                 7          1  Life Sciences              1            1492
# 2                 9          3        Medical              1            1494
# 3                13          2  Life Sciences              1            1495
# 4                 2          1        Medical              1            1496
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# ...

# %% [markdown]
# # HR ANALYTICS

# %%
hr_analytics=pd.read_csv('https://raw.githubusercontent.com/Nyakiamo-Samuel/HR-Analysis/refs/heads/main/HR_analytics.csv')
hr_analytics.head()
# Out:
#    Unnamed: 0  department  region  education  gender  recruitment_channel  \
# 0           0           7      31          2       0                    2
# 1           1           4      14          0       1                    0
# 2           2           7      10          0       1                    2
# 3           3           7      15          0       1                    0
# 4           4           8      18          0       1                    0
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# 0              1            0                  49            0
# ...

# %% [markdown]
# # HR CSV

# %%
hr_csv=pd.read_csv('https://raw.githubusercontent.com/Nyakiamo-Samuel/HR-Analysis/refs/heads/main/HR_comma_sep.csv')
hr_csv.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...
